# %% [markdown]
# # Book IV
# # Proposition 15
# To inscribe an equilateral and equiangular hexagon in a given circle.
# ![image.png](attachment:95d13960-ff4c-4b5f-bf2f-71869fafcf83.png)
# # Corollary
# The side of the hexagon equals the radius of the circle
