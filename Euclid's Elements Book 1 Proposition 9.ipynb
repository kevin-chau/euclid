# %% [markdown]
# # Book 1 Proposition 9
# To bisect a given rectiliniear angle
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
